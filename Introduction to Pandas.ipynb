# %%
import pandas as pd
data = {"Name":["John","Peter","Lisa"],
        "Age":[25,28,31],
       "Salary":[30000,45000,25000]}
df = pd.DataFrame(data)
print (df)
# Out:
#     Name  Age  Salary
# 0   John   25   30000
# 1  Peter   28   45000
# 2   Lisa   31   25000

# %%
import pandas as pd
data = pd.read_csv("C:/Users/HP/Downloads/pandas_practice.csv")

print (data)
# Out:
#     Name  Age        City  Sales
# 0  Rahim   22       Dhaka  15000
# 1  Karim   25  Chattogram  22000
# 2  Hasan   21      Sylhet  18000
# 3  Nadia   24       Dhaka  25000
# 4  Sadia   23    Rajshahi  12000

# %%
#exploring data in pandas
import pandas as pd

data = pd.read_excel("C:/Users/HP/Downloads/pandas_practice.xlsx")
print (data)
# Out:
#     Name  Age        City  Sales
# 0  Rahim   22       Dhaka  15000
# 1  Karim   25  Chattogram  22000
# 2  Hasan   21      Sylhet  18000
# 3  Nadia   24       Dhaka  25000
# 4  Sadia   23    Rajshahi  12000

# %%
import pandas as pd
data = pd.read_excel("C:/Users/HP/Downloads/pandas_practice.xlsx")
print (data.head(2))
print (data.tail(2))
# Out:
#     Name  Age        City  Sales
# 0  Rahim   22       Dhaka  15000
# 1  Karim   25  Chattogram  22000
#     Name  Age      City  Sales
# 3  Nadia   24     Dhaka  25000
# 4  Sadia   23  Rajshahi  12000

# %%
print (data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    5 non-null      object
#  1   Age     5 non-null      int64
#  2   City    5 non-null      object
#  3   Sales   5 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 292.0+ bytes
# None

# %%
data.describe()
# Out:
#              Age         Sales
# count   5.000000      5.000000
# mean   23.000000  18400.000000
# std     1.581139   5224.940191
# min    21.000000  12000.000000
# 25%    22.000000  15000.000000
# 50%    23.000000  18000.000000
# 75%    24.000000  22000.000000
# max    25.000000  25000.000000

# %%
print (data.isnull().sum())
# Out:
# Name     0
# Age      0
# City     0
# Sales    0
# dtype: int64

# %%
#handling duplicate values in pandas
import pandas as pd

data = pd.read_csv("C:/Users/HP/Downloads/pandas_practice.csv")
print(data)

#import pandas as pd

#data = pd.read_csv("pandas_practice.csv")
#print (data)
# Out:
#     Name  Age        City  Sales
# 0  Rahim   22       Dhaka  15000
# 1  Karim   25  Chattogram  22000
# 2  Hasan   21      Sylhet  18000
# 3  Nadia   24       Dhaka  25000
# 4  Sadia   23    Rajshahi  12000

# %%
import pandas as pd
data = pd.read_csv("C:/Users/HP/Downloads/employee_sales_practice.csv")
print (data)
# Out:
#     ID     Name   Age        City Department   Salary    Sales    JoinDate
# 0    1    Rahim  22.0       Dhaka      Sales  25000.0  15000.0  2022-01-15
# 1    2    Karim  25.0  Chattogram  Marketing  30000.0  22000.0  2021-06-10
# 2    3    Hasan  21.0      Sylhet      Sales  24000.0  18000.0  2023-03-01
# 3    4    Nadia  24.0       Dhaka         IT  35000.0  25000.0  2020-11-20
# 4    5    Sadia  23.0    Rajshahi  Marketing  28000.0  12000.0  2022-09-05
# 5    6    Rakib  29.0       Dhaka         IT  40000.0      NaN  2019-02-14
# 6    7    Tania  26.0      Khulna      Sales  26000.0  19000.0  2021-07-19
# 7    8    Jahid  31.0  Chattogram    Finance  45000.0      NaN  2018-05-30
# 8    9      Mim  22.0       Dhaka  Marketing      NaN  17000.0  2023-01-10
# 9   10   Sabbir  27.0      Sylhet         IT  38000.0  21000.0  2020-08-25
# 10  11    Rakib  29.0       Dhaka         IT  40000.0  20000.0  2019-02-14
# ...

# %%
print(data["ID"].duplicated().sum())
# Out:
# 0

# %%
#Handling Null Values

import pandas as pd 
data = pd.read_csv("C:/Users/HP/Downloads/employee_sales_practice.csv")
print (data)
# Out:
#     ID     Name   Age        City Department   Salary    Sales    JoinDate
# 0    1    Rahim  22.0       Dhaka      Sales  25000.0  15000.0  2022-01-15
# 1    2    Karim  25.0  Chattogram  Marketing  30000.0  22000.0  2021-06-10
# 2    3    Hasan  21.0      Sylhet      Sales  24000.0  18000.0  2023-03-01
# 3    4    Nadia  24.0       Dhaka         IT  35000.0  25000.0  2020-11-20
# 4    5    Sadia  23.0    Rajshahi  Marketing  28000.0  12000.0  2022-09-05
# 5    6    Rakib  29.0       Dhaka         IT  40000.0      NaN  2019-02-14
# 6    7    Tania  26.0      Khulna      Sales  26000.0  19000.0  2021-07-19
# 7    8    Jahid  31.0  Chattogram    Finance  45000.0      NaN  2018-05-30
# 8    9      Mim  22.0       Dhaka  Marketing      NaN  17000.0  2023-01-10
# 9   10   Sabbir  27.0      Sylhet         IT  38000.0  21000.0  2020-08-25
# 10  11    Rakib  29.0       Dhaka         IT  40000.0  20000.0  2019-02-14
# ...

# %%
print(data.isnull())
# Out:
#        ID   Name    Age   City  Department  Salary  Sales  JoinDate
# 0   False  False  False  False       False   False  False     False
# 1   False  False  False  False       False   False  False     False
# 2   False  False  False  False       False   False  False     False
# 3   False  False  False  False       False   False  False     False
# 4   False  False  False  False       False   False  False     False
# 5   False  False  False  False       False   False   True     False
# 6   False  False  False  False       False   False  False     False
# 7   False  False  False  False       False   False   True     False
# 8   False  False  False  False       False    True  False     False
# 9   False  False  False  False       False   False  False     False
# 10  False  False  False  False       False   False  False     False
# 11  False  False  False  False       False   False  False     False
# 12  False  False  False  False       False   False   True     False
# ...

# %%
print(data.isnull().sum())
# Out:
# ID            0
# Name          0
# Age           1
# City          0
# Department    0
# Salary        3
# Sales         8
# JoinDate      0
# dtype: int64

# %%
print(data.dropna())
# Out:
#     ID     Name   Age        City Department   Salary    Sales    JoinDate
# 0    1    Rahim  22.0       Dhaka      Sales  25000.0  15000.0  2022-01-15
# 1    2    Karim  25.0  Chattogram  Marketing  30000.0  22000.0  2021-06-10
# 2    3    Hasan  21.0      Sylhet      Sales  24000.0  18000.0  2023-03-01
# 3    4    Nadia  24.0       Dhaka         IT  35000.0  25000.0  2020-11-20
# 4    5    Sadia  23.0    Rajshahi  Marketing  28000.0  12000.0  2022-09-05
# 6    7    Tania  26.0      Khulna      Sales  26000.0  19000.0  2021-07-19
# 9   10   Sabbir  27.0      Sylhet         IT  38000.0  21000.0  2020-08-25
# 10  11    Rakib  29.0       Dhaka         IT  40000.0  20000.0  2019-02-14
# 11  12  Farhana  24.0    Rajshahi      Sales  25500.0  16000.0  2022-04-12
# 13  14   Nusrat  21.0       Dhaka  Marketing  27000.0  13000.0  2023-06-15
# 14  15   Shakil  28.0  Chattogram         IT  39000.0  23000.0  2020-02-20
# ...

# %%
print(data)
# Out:
#     ID     Name   Age        City Department   Salary    Sales    JoinDate
# 0    1    Rahim  22.0       Dhaka      Sales  25000.0  15000.0  2022-01-15
# 1    2    Karim  25.0  Chattogram  Marketing  30000.0  22000.0  2021-06-10
# 2    3    Hasan  21.0      Sylhet      Sales  24000.0  18000.0  2023-03-01
# 3    4    Nadia  24.0       Dhaka         IT  35000.0  25000.0  2020-11-20
# 4    5    Sadia  23.0    Rajshahi  Marketing  28000.0  12000.0  2022-09-05
# 5    6    Rakib  29.0       Dhaka         IT  40000.0      NaN  2019-02-14
# 6    7    Tania  26.0      Khulna      Sales  26000.0  19000.0  2021-07-19
# 7    8    Jahid  31.0  Chattogram    Finance  45000.0      NaN  2018-05-30
# 8    9      Mim  22.0       Dhaka  Marketing      NaN  17000.0  2023-01-10
# 9   10   Sabbir  27.0      Sylhet         IT  38000.0  21000.0  2020-08-25
# 10  11    Rakib  29.0       Dhaka         IT  40000.0  20000.0  2019-02-14
# ...

# %%
import numpy as np
print(data.replace(np.nan,30000))
# Out:
#     ID     Name      Age        City Department   Salary    Sales    JoinDate
# 0    1    Rahim     22.0       Dhaka      Sales  25000.0  15000.0  2022-01-15
# 1    2    Karim     25.0  Chattogram  Marketing  30000.0  22000.0  2021-06-10
# 2    3    Hasan     21.0      Sylhet      Sales  24000.0  18000.0  2023-03-01
# 3    4    Nadia     24.0       Dhaka         IT  35000.0  25000.0  2020-11-20
# 4    5    Sadia     23.0    Rajshahi  Marketing  28000.0  12000.0  2022-09-05
# 5    6    Rakib     29.0       Dhaka         IT  40000.0  30000.0  2019-02-14
# 6    7    Tania     26.0      Khulna      Sales  26000.0  19000.0  2021-07-19
# 7    8    Jahid     31.0  Chattogram    Finance  45000.0  30000.0  2018-05-30
# 8    9      Mim     22.0       Dhaka  Marketing  30000.0  17000.0  2023-01-10
# 9   10   Sabbir     27.0      Sylhet         IT  38000.0  21000.0  2020-08-25
# 10  11    Rakib     29.0       Dhaka         IT  40000.0  20000.0  2019-02-14
# ...

# %%
import numpy as np
data["Salary"] = data["Salary"].replace(np.nan,33523.333333333336) 
print (data)
print (data["Salary"].mean())
# Out:
#     ID     Name   Age        City Department   Salary    Sales    JoinDate
# 0    1    Rahim  22.0       Dhaka      Sales  25000.0  15000.0  2022-01-15
# 1    2    Karim  25.0  Chattogram  Marketing  30000.0  22000.0  2021-06-10
# 2    3    Hasan  21.0      Sylhet      Sales  24000.0  18000.0  2023-03-01
# 3    4    Nadia  24.0       Dhaka         IT  35000.0  25000.0  2020-11-20
# 4    5    Sadia  23.0    Rajshahi  Marketing  28000.0  12000.0  2022-09-05
# 5    6    Rakib  29.0       Dhaka         IT  40000.0      NaN  2019-02-14
# 6    7    Tania  26.0      Khulna      Sales  26000.0  19000.0  2021-07-19
# 7    8    Jahid  31.0  Chattogram    Finance  45000.0      NaN  2018-05-30
# 8    9      Mim  22.0       Dhaka  Marketing  30000.0  17000.0  2023-01-10
# 9   10   Sabbir  27.0      Sylhet         IT  38000.0  21000.0  2020-08-25
# 10  11    Rakib  29.0       Dhaka         IT  40000.0  20000.0  2019-02-14
# ...

# %%
print (data["Salary"].mean())
# Out:
# 33523.333333333336

# %%
print (data)
# Out:
#     ID     Name   Age        City Department   Salary    Sales    JoinDate
# 0    1    Rahim  22.0       Dhaka      Sales  25000.0  15000.0  2022-01-15
# 1    2    Karim  25.0  Chattogram  Marketing  30000.0  22000.0  2021-06-10
# 2    3    Hasan  21.0      Sylhet      Sales  24000.0  18000.0  2023-03-01
# 3    4    Nadia  24.0       Dhaka         IT  35000.0  25000.0  2020-11-20
# 4    5    Sadia  23.0    Rajshahi  Marketing  28000.0  12000.0  2022-09-05
# 5    6    Rakib  29.0       Dhaka         IT  40000.0      NaN  2019-02-14
# 6    7    Tania  26.0      Khulna      Sales  26000.0  19000.0  2021-07-19
# 7    8    Jahid  31.0  Chattogram    Finance  45000.0      NaN  2018-05-30
# 8    9      Mim  22.0       Dhaka  Marketing      NaN  17000.0  2023-01-10
# 9   10   Sabbir  27.0      Sylhet         IT  38000.0  21000.0  2020-08-25
# 10  11    Rakib  29.0       Dhaka         IT  40000.0  20000.0  2019-02-14
# ...

# %%
print(data.bfill())
# Out:
#     ID     Name   Age        City Department   Salary    Sales    JoinDate
# 0    1    Rahim  22.0       Dhaka      Sales  25000.0  15000.0  2022-01-15
# 1    2    Karim  25.0  Chattogram  Marketing  30000.0  22000.0  2021-06-10
# 2    3    Hasan  21.0      Sylhet      Sales  24000.0  18000.0  2023-03-01
# 3    4    Nadia  24.0       Dhaka         IT  35000.0  25000.0  2020-11-20
# 4    5    Sadia  23.0    Rajshahi  Marketing  28000.0  12000.0  2022-09-05
# 5    6    Rakib  29.0       Dhaka         IT  40000.0  19000.0  2019-02-14
# 6    7    Tania  26.0      Khulna      Sales  26000.0  19000.0  2021-07-19
# 7    8    Jahid  31.0  Chattogram    Finance  45000.0  17000.0  2018-05-30
# 8    9      Mim  22.0       Dhaka  Marketing  38000.0  17000.0  2023-01-10
# 9   10   Sabbir  27.0      Sylhet         IT  38000.0  21000.0  2020-08-25
# 10  11    Rakib  29.0       Dhaka         IT  40000.0  20000.0  2019-02-14
# ...

# %%
print(data.ffill())
# Out:
#     ID     Name   Age        City Department   Salary    Sales    JoinDate
# 0    1    Rahim  22.0       Dhaka      Sales  25000.0  15000.0  2022-01-15
# 1    2    Karim  25.0  Chattogram  Marketing  30000.0  22000.0  2021-06-10
# 2    3    Hasan  21.0      Sylhet      Sales  24000.0  18000.0  2023-03-01
# 3    4    Nadia  24.0       Dhaka         IT  35000.0  25000.0  2020-11-20
# 4    5    Sadia  23.0    Rajshahi  Marketing  28000.0  12000.0  2022-09-05
# 5    6    Rakib  29.0       Dhaka         IT  40000.0  12000.0  2019-02-14
# 6    7    Tania  26.0      Khulna      Sales  26000.0  19000.0  2021-07-19
# 7    8    Jahid  31.0  Chattogram    Finance  45000.0  19000.0  2018-05-30
# 8    9      Mim  22.0       Dhaka  Marketing  45000.0  17000.0  2023-01-10
# 9   10   Sabbir  27.0      Sylhet         IT  38000.0  21000.0  2020-08-25
# 10  11    Rakib  29.0       Dhaka         IT  40000.0  20000.0  2019-02-14
# ...

# %%
#Columns Transformation in pandas Part-1
import pandas as pd

data = pd.read_excel("C:/Users/HP/Downloads/employee_sales_practice.xlsx")
print(data)

print (data[["Name","Salary"]])
# Out:
#    ID   Name  Age        City Department   Salary    Sales    JoinDate
# 0   1  Rahim   22       Dhaka      Sales  25000.0  15000.0  2022-01-15
# 1   2  Karim   25  Chattogram  Marketing  30000.0  22000.0  2021-06-10
# 2   3  Hasan   21      Sylhet      Sales  24000.0  18000.0  2023-03-01
# 3   4  Nadia   24       Dhaka         IT  35000.0      NaN  2020-11-20
# 4   5  Sadia   23    Rajshahi  Marketing      NaN  12000.0  2022-09-05
# 5   6  Rakib   29       Dhaka         IT  40000.0  20000.0  2019-02-14
# 6   7  Rakib   29       Dhaka         IT  40000.0  20000.0  2019-02-14
#     Name   Salary
# 0  Rahim  25000.0
# 1  Karim  30000.0
# 2  Hasan  24000.0
# 3  Nadia  35000.0
# 4  Sadia      NaN
# 5  Rakib  40000.0
# 6  Rakib  40000.0

# %%
print(data.groupby("Department")["Salary"].mean())
# Out:
# Department
# IT           38333.333333
# Marketing    30000.000000
# Sales        24500.000000
# Name: Salary, dtype: float64

# %%
print(data.sort_values("Salary"))
# Out:
#    ID   Name  Age        City Department   Salary    Sales    JoinDate
# 2   3  Hasan   21      Sylhet      Sales  24000.0  18000.0  2023-03-01
# 0   1  Rahim   22       Dhaka      Sales  25000.0  15000.0  2022-01-15
# 1   2  Karim   25  Chattogram  Marketing  30000.0  22000.0  2021-06-10
# 3   4  Nadia   24       Dhaka         IT  35000.0      NaN  2020-11-20
# 5   6  Rakib   29       Dhaka         IT  40000.0  20000.0  2019-02-14
# 6   7  Rakib   29       Dhaka         IT  40000.0  20000.0  2019-02-14
# 4   5  Sadia   23    Rajshahi  Marketing      NaN  12000.0  2022-09-05

# %%
#columnsa transformation in pandas part-2
import pandas as pd
data = pd.read_excel("C:/Users/HP/Downloads/employee_sales_practice.xlsx")
print (data)

data["Bonus"] = (data["Salary"]/100)*20
print(data)
# Out:
#    ID   Name  Age        City Department   Salary    Sales    JoinDate
# 0   1  Rahim   22       Dhaka      Sales  25000.0  15000.0  2022-01-15
# 1   2  Karim   25  Chattogram  Marketing  30000.0  22000.0  2021-06-10
# 2   3  Hasan   21      Sylhet      Sales  24000.0  18000.0  2023-03-01
# 3   4  Nadia   24       Dhaka         IT  35000.0      NaN  2020-11-20
# 4   5  Sadia   23    Rajshahi  Marketing      NaN  12000.0  2022-09-05
# 5   6  Rakib   29       Dhaka         IT  40000.0  20000.0  2019-02-14
# 6   7  Rakib   29       Dhaka         IT  40000.0  20000.0  2019-02-14
#    ID   Name  Age        City Department   Salary    Sales    JoinDate   Bonus
# 0   1  Rahim   22       Dhaka      Sales  25000.0  15000.0  2022-01-15  5000.0
# 1   2  Karim   25  Chattogram  Marketing  30000.0  22000.0  2021-06-10  6000.0
# 2   3  Hasan   21      Sylhet      Sales  24000.0  18000.0  2023-03-01  4800.0
# 3   4  Nadia   24       Dhaka         IT  35000.0      NaN  2020-11-20  7000.0
# ...

# %%
data = {"Months":["January","February","March","April"]}
a = pd.DataFrame(data)
print (a)

def extract(value):
    return value[0:3]
    
a["Short_months"] = a["Months"].map(extract)
print (a)
# Out:
#      Months
# 0   January
# 1  February
# 2     March
# 3     April
#      Months Short_months
# 0   January          Jan
# 1  February          Feb
# 2     March          Mar
# 3     April          Apr

# %%
#Group By in Pandas
import pandas as pd

data = pd.read_excel("C:/Users/HP/Downloads/employee_sales_practice.xlsx")
print (data.head(3))
# Out:
#    ID   Name  Age        City Department   Salary    Sales    JoinDate
# 0   1  Rahim   22       Dhaka      Sales  25000.0  15000.0  2022-01-15
# 1   2  Karim   25  Chattogram  Marketing  30000.0  22000.0  2021-06-10
# 2   3  Hasan   21      Sylhet      Sales  24000.0  18000.0  2023-03-01

# %%
gp = data.groupby("Department").agg({"City":"count"})
print (gp)
# Out:
#             City
# Department
# IT             3
# Marketing      2
# Sales          2

# %%
gp = data.groupby("City").agg({"Salary":"count"})
print (gp)
# Out:
#             Salary
# City
# Chattogram       1
# Dhaka            4
# Rajshahi         0
# Sylhet           1

# %%
gp = data.groupby("Department").agg({"ID":"count"})
print (gp)
# Out:
#             ID
# Department
# IT           3
# Marketing    2
# Sales        2

# %%
# Merge,Join and Concatenate in Pandas
import pandas as pd

data = pd.read_excel("C:/Users/HP/Downloads/employee_sales_practice.xlsx")
print(data)

data1 ={"Emp ID":["01","02","03","04","05"],
        "Name":["Rakib","Sakib","Rima","Mina","sima"],
       "Age":[34,55,33,24,46]}

data2 = {"Emp ID":["01","02","03","04","05"],
        "Salary":[45000,56000,34000,30000,50000]}

df1 = pd.DataFrame(data1)
df2 =pd.DataFrame(data2)

print(df1)
print()
print(df2)
# Out:
#    ID   Name  Age        City Department   Salary    Sales    JoinDate
# 0   1  Rahim   22       Dhaka      Sales  25000.0  15000.0  2022-01-15
# 1   2  Karim   25  Chattogram  Marketing  30000.0  22000.0  2021-06-10
# 2   3  Hasan   21      Sylhet      Sales  24000.0  18000.0  2023-03-01
# 3   4  Nadia   24       Dhaka         IT  35000.0      NaN  2020-11-20
# 4   5  Sadia   23    Rajshahi  Marketing      NaN  12000.0  2022-09-05
# 5   6  Rakib   29       Dhaka         IT  40000.0  20000.0  2019-02-14
# 6   7  Rakib   29       Dhaka         IT  40000.0  20000.0  2019-02-14
#   Emp ID   Name  Age
# 0     01  Rakib   34
# 1     02  Sakib   55
# 2     03   Rima   33
# 3     04   Mina   24
# 4     05   sima   46
#
#   Emp ID  Salary
# 0     01   45000
# 1     02   56000
# 2     03   34000
# 3     04   30000
# 4     05   50000

# %%
print(pd.merge(df1,df2,on ="Emp ID"))
# Out:
#   Emp ID   Name  Age  Salary
# 0     01  Rakib   34   45000
# 1     02  Sakib   55   56000
# 2     03   Rima   33   34000
# 3     04   Mina   24   30000
# 4     05   sima   46   50000

# %%
data1 ={"Emp ID":["01","02","03","04","05"],
        "Name":["Rakib","Sakib","Rima","Mina","sima"],
       "Age":[34,55,33,24,46]}

data2 = {"Emp ID":["01","02","07","04","08"],
        "Salary":[45000,56000,34000,30000,50000]}

df1 = pd.DataFrame(data1)
df2 =pd.DataFrame(data2)

print(df1)
print()
print(df2)

print()
print(pd.merge( left = df1,right = df2,on ="Emp ID",how = "left"))
# Out:
#   Emp ID   Name  Age
# 0     01  Rakib   34
# 1     02  Sakib   55
# 2     03   Rima   33
# 3     04   Mina   24
# 4     05   sima   46
#
#   Emp ID  Salary
# 0     01   45000
# 1     02   56000
# 2     07   34000
# 3     04   30000
# 4     08   50000
#
#   Emp ID   Name  Age   Salary
# 0     01  Rakib   34  45000.0
# 1     02  Sakib   55  56000.0
# 2     03   Rima   33      NaN
# 3     04   Mina   24  30000.0
# 4     05   sima   46      NaN

# %%
print(pd.merge( left = df1,right = df2,on ="Emp ID",how = "right"))
# Out:
#   Emp ID   Name   Age  Salary
# 0     01  Rakib  34.0   45000
# 1     02  Sakib  55.0   56000
# 2     07    NaN   NaN   34000
# 3     04   Mina  24.0   30000
# 4     08    NaN   NaN   50000

# %%
print(pd.join(df1,df2))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 print(pd.join(df1,df2))
#
# AttributeError: module 'pandas' has no attribute 'join'

# %%
import pandas as pd

data1 ={"Emp ID":["01","02","03","04","05"],
        "Name":["Rakib","Sakib","Rima","Mina","sima"],
       "Age":[34,55,33,24,46]}

data2 = {"Emp ID":["06","07","08","09","10"],
        "Name":["Raj","Sakiba","Riman","Minal","siman"],
       "Age":[34,55,33,24,46]}

df1 = pd.DataFrame(data1)
df2 = pd.DataFrame(data2)
print(df1)
print()
print(df2)
# Out:
#   Emp ID   Name  Age
# 0     01  Rakib   34
# 1     02  Sakib   55
# 2     03   Rima   33
# 3     04   Mina   24
# 4     05   sima   46
#
#   Emp ID    Name  Age
# 0     06     Raj   34
# 1     07  Sakiba   55
# 2     08   Riman   33
# 3     09   Minal   24
# 4     10   siman   46

# %%
print(pd.concat([df1,df2]))
# Out:
#   Emp ID    Name  Age
# 0     01   Rakib   34
# 1     02   Sakib   55
# 2     03    Rima   33
# 3     04    Mina   24
# 4     05    sima   46
# 0     06     Raj   34
# 1     07  Sakiba   55
# 2     08   Riman   33
# 3     09   Minal   24
# 4     10   siman   46

# %%
#Pandas Compare DataFrames
import pandas as pd
dict = {"Fruits":["mango","apple","banana","papaya"],
       "Price":[100,150,50,35],
       "Quantity":[15,10,10,3]}
df1 = pd.DataFrame(dict)
print(df1)

df2 = df1.copy()
print (df2)

df2.loc[0,"Price"]=120
df2.loc[1,"Price"]=175
df2.loc[3,"Price"]=30
df2.loc[0,"Quantity"]=12
df2.loc[1,"Quantity"]=15
df2.loc[3,"Quantity"]=5

print(df2)

print(df1.compare(df2,align_axis=0))

print(df1.compare(df2,keep_equal=True))
print(df1.compare(df2,keep_shape=True))
print(df1.compare(df2,keep_shape=False))
# Out:
#    Fruits  Price  Quantity
# 0   mango    100        15
# 1   apple    150        10
# 2  banana     50        10
# 3  papaya     35         3
#    Fruits  Price  Quantity
# 0   mango    100        15
# 1   apple    150        10
# 2  banana     50        10
# 3  papaya     35         3
#    Fruits  Price  Quantity
# 0   mango    120        12
# 1   apple    175        15
# 2  banana     50        10
# 3  papaya     30         5
#          Price  Quantity
# 0 self   100.0      15.0
#   other  120.0      12.0
# 1 self   150.0      10.0
#   other  175.0      15.0
# 3 self    35.0       3.0
#   other   30.0       5.0
#   Price       Quantity
#    self other     self other
# 0   100   120       15    12
# 1   150   175       10    15
# 3    35    30        3     5
#   Fruits        Price        Quantity
#     self other   self  other     self other
# 0    NaN   NaN  100.0  120.0     15.0  12.0
# 1    NaN   NaN  150.0  175.0     10.0  15.0
# 2    NaN   NaN    NaN    NaN      NaN   NaN
# ...

# %%
# Pandas -Pivoting and Melting DataFrames
import pandas as pd

dict ={"keys":["k1","k2","k1","k2"],
      "Names":["John","Ben","David","Peter"],
     "Houses":["red","blue","green","red"]}

df =pd.DataFrame(dict)
print (df)
print(df.pivot(index="keys", columns="Names", values="Houses"))
# Out:
#   keys  Names Houses
# 0   k1   John    red
# 1   k2    Ben   blue
# 2   k1  David  green
# 3   k2  Peter    red
# Names   Ben  David John Peter
# keys
# k1      NaN  green  red   NaN
# k2     blue    NaN  NaN   red

# %%
import pandas as pd

dict ={"keys":["k1","k2","k1","k2"],
      "Names":["John","Ben","David","Peter"],
     "Houses":["red","blue","green","red"],
      "Grades":["3rd","8th","9th","8th"]}

df =pd.DataFrame(dict)
print (df)
print(df.pivot(index="keys", columns="Names", values=["Houses","Grades"]))
# Out:
#   keys  Names Houses Grades
# 0   k1   John    red    3rd
# 1   k2    Ben   blue    8th
# 2   k1  David  green    9th
# 3   k2  Peter    red    8th
#       Houses                   Grades
# Names    Ben  David John Peter    Ben David John Peter
# keys
# k1       NaN  green  red   NaN    NaN   9th  3rd   NaN
# k2      blue    NaN  NaN   red    8th   NaN  NaN   8th

# %%
# Melting DataFrames

import pandas as pd

dict ={"Names":["John","Ben","David","Peter"],
     "Houses":["red","blue","green","red"],
      "Grades":["3rd","8th","9th","8th"]}

df = pd.DataFrame(dict)
print(df)
print()
print(pd.melt(df,id_vars=["Names"],value_vars=["Houses","Grades"]))
print()
print(pd.melt(df,id_vars=["Names"],value_vars=["Houses","Grades"],var_name="Houses&Grades",value_name="values"))
# Out:
#    Names Houses Grades
# 0   John    red    3rd
# 1    Ben   blue    8th
# 2  David  green    9th
# 3  Peter    red    8th
#
#    Names variable  value
# 0   John   Houses    red
# 1    Ben   Houses   blue
# 2  David   Houses  green
# 3  Peter   Houses    red
# 4   John   Grades    3rd
# 5    Ben   Grades    8th
# 6  David   Grades    9th
# 7  Peter   Grades    8th
#
#    Names Houses&Grades values
# 0   John        Houses    red
# 1    Ben        Houses   blue
# 2  David        Houses  green
# 3  Peter        Houses    red
# 4   John        Grades    3rd
# 5    Ben        Grades    8th
# 6  David        Grades    9th
# 7  Peter        Grades    8th
