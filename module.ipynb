# %%
import demo01

a = demo01.add(2, 3)
print(a)
# Out:
# 5

# %%
import demo01 as d

a = d.add(2,3)
print (a)
# Out:
# 5

# %%
import demo01

b = demo01.employee["Name"]
print(b)
# Out:
# Mahbub

# %%
import importlib
import demo01

importlib.reload(demo01)

print(demo01.employee["Name"])
# Out:
# Mahbub

# %%
import demo01

b = demo01.employee["Name"]
print(b)
# Out:
# Mahbub
