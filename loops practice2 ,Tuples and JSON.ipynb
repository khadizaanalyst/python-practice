# %%
#endswith() -returns true if the string ends with the specified value
a = "Harry Potter"
print(a.endswith("r"))
print (a.endswith("t",6,9))


#startswith() -returns true if the string starts with the specified value
a = "Harry Potter"
print (a.startswith("H"))
print (a.startswith("P",6,9))

#swapcase() -swaps cases,lower case becomes upper case and vice versa
a = "Harry Potter"
print (a.swapcase())

#strip() - returns a trimmed version of the string
a = "  ***** Harry Potter *****  "
print (a)
print (a.strip(". ,*,"))

#spilt() - spilts the string at the specified separator, and retuns  a list
a ="#OOFD#BRB#OMW#TB"
b = "hello.my name is dear.i am 23 years old"
print (a.split("#"))
print (b.split("."))

#ljust() - returns a left justified version of the string
a = "Harry Potter"
x = a.ljust (20,"*")
print (x, "is my favourite movie")

#rjust() - returns a right justified version of the string
a = "Harry Potter"
x = a.rjust(20, "$")
print (x, "is my favourite movie")

#replace() - returns a string where a specvified value is replaced with a
# specifiied vallue
a = "my name is dear"
print (a.replace ("dear","janu"))

#rindex() - searches the string for a specified value and returns 
# the last position of where it was found
a = "Harry Potter and the Prisoner of Azkaban"
print (a.rindex("Prisoner"))
print (a.rindex("Harry"))

#rfind() - searches the string for a specified value and returns 
# the last position of where it was found
a = "Harry potter and the Goblet of Fire"
print (a.rfind("potter"))
a = "bibidy bobidy boo"
print (a.rfind("dy",6,14))
# Out:
# True
# True
# True
# True
# hARRY pOTTER
#   ***** Harry Potter *****
# Harry Potter
# ['', 'OOFD', 'BRB', 'OMW', 'TB']
# ['hello', 'my name is dear', 'i am 23 years old']
# Harry Potter******** is my favourite movie
# $$$$$$$$Harry Potter is my favourite movie
# my name is janu
# 21
# 0
# 6
# 11

# %%
#string slicing
a = "Harry Potter and the Goblet of the Fire"
b = "0123456789"
print (a)
print (b)
print (b[::2])
print (b[:7:2])
print (b[::-1])
print (b[6::-1])


print (a[0:5])
print (a[6:12])
print (a[:5])
print (a[-4:])
# Out:
# Harry Potter and the Goblet of the Fire
# 0123456789
# 02468
# 0246
# 9876543210
# 6543210
# Harry
# Potter
# Harry
# Fire

# %%
#fibonacci series
a = 0
b = 1
n = int(input("enter a number here: "))
if n == 1:
    print (1)
else:
    print (a)
print (b)
for i in range (2,n):
    c = a+b
    a = b
    b = c
    print (c)
# Out:
# enter a number here:  3
# 0
# 1
# 1

# %%
#if number is prime or not

num =int (input("enter a number here: "))

if num <= 1:
    print ("it is not a prime number")
else:

    for i in range (2,num):
        if num % i == 0:
            print ("number is not a prime number")
    else:
        print ("it is a prime number")
# Out:
# enter a number here:  2
# it is a prime number

# %%
num = int(input("enter a number here: "))

if num <= 1:
    print ("it is not a prime number")
else:
    for i in range (2,num):
        if num% i == 0:
            print ("number is not a prime number")
            break
    else:

        print ("it is a prime number")
# Out:
# enter a number here:  2
# it is a prime number

# %%
#check for palindrome
num = int(input("enter a number here"))
temp = num
rev = 0
while num >0:
    dig = num%10
    rev = rev*10 + dig
    num = num // 10

if rev == temp:
    print ("it is palindrome")
else:
    print ("it is not a palindrome")
# Out:
# enter a number here 12
# it is not a palindrome

# %%
# area calculator

print("*****area calculator*****")
while True:
    print("""Press 1 to get the area of square
    Press 2 to get the area of rectangle
    Press 3 to get the area of circle
    Press 4 to get the area of triangle""")
    
    choice = int(input("Enter a number between 1-4: "))
    
    if choice == 1:
        while True:
            side = float(input("Enter the length of one side: "))
            area = side ** 2
            print("The area of square is", area)
            repeat = input ("do you want to try again with square? ")
            if repeat == "no":
                break

    elif choice == 2:
        while True:
            length = float(input("Enter the length of the rectangle: "))
            width = float(input("Enter the width of the rectangle: "))
            area = length * width
            print("The area of rectangle is", area)
            repeat = input ("do you want to try again with rectangle? ")
            if repeat == "no":
                break
            
        
    elif choice == 3:
        while True:
            radius = float(input("Enter the radius of the circle: "))
            area = (22 / 7) * (radius ** 2)
            print("The area of the circle is", area)
            repeat = input ("do you want to try again with circle? ")
            if repeat == "no":
                break
        
    elif choice == 4:
        while True:
            base = float(input("Enter the base of the triangle: "))
            height = float(input("Enter the height of the triangle: "))
            area = 0.5 * base * height
            print("The area of the triangle is", area)
            repeat = input ("do you want to try again with tringle? ")
            if repeat == "no":
                break
    repeat1 = input ("do you want to repeat the menu again")
    if repeat1 == "no":
        break
# Out:
# *****area calculator*****
# Press 1 to get the area of square
#     Press 2 to get the area of rectangle
#     Press 3 to get the area of circle
#     Press 4 to get the area of triangle
# Enter a number between 1-4:  2
# Enter the length of the rectangle:  3
# Enter the width of the rectangle:  2
# The area of rectangle is 6.0
# do you want to try again with rectangle?  no
# do you want to repeat the menu again yes
# Press 1 to get the area of square
#     Press 2 to get the area of rectangle
#     Press 3 to get the area of circle
#     Press 4 to get the area of triangle
# Enter a number between 1-4:  4
# Enter the base of the triangle:  5
# Enter the height of the triangle:  3
# The area of the triangle is 7.5
# do you want to try again with tringle?  no
# do you want to repeat the menu again no

# %%
# write a program to separate the following string 
# into comma (,) separated value.

a = "OOTD.YOLO.ASAP.BRB.GTG.OTW"
b = a.split(".")
print (b)
# write a program to sort strings alphabetically in python.
a = input ("enter anything here: ")
b = sorted (a)
print (b)

#write a program to remove a given character from a string.

a = "hello"
b = a.replace("e","")
print (b)
g = "F.R.I.E.N.D.S."
B  = g.replace(".","")
print (B)
#write a program to check the number of occurance of a 
#substring in a string

a = "she sells seasells on the sea shore"
b = a.count("sea")
print ("the number of timer substring sea is occring is",b)
# Out:
# ['OOTD', 'YOLO', 'ASAP', 'BRB', 'GTG', 'OTW']
# enter anything here:  hello
# ['e', 'h', 'l', 'l', 'o']
# hllo
# FRIENDS
# the number of timer substring sea is occring is 2

# %%
# take an input from a user as a string then, reverse it.
a = input ("enter anything here: ")
print (a[::-1])
#write a program to check if a string contains only digits.
a = input ("enter anything here: ")
print (a.isdigit())
if b == True:
    print ("it contains only digits")
else:
    print ("it does not contain only digits")
# Out:
# enter anything here:  3
# 3
# enter anything here:  5
# True
# it does not contain only digits

# %%
#write a program to check if a string is palindrome.
a = input ("enter anything here: ")
rev = a[::-1]

if a == rev:
    print ("it is palindrome")
else:
    print ("it is not palindrome")
# Out:
# enter anything here:  23
# it is not palindrome

# %%
#write a program to find number of vowels in a string.
a = input ("enter anything here: ")
vowels =  0
for i in a:
    if i == "a" or i == "e" or i == "i" or i == "o" or i == "u" or  i == "A" or i == "E" or i == "I" or i == "O" or i == "U" :
        vowels +=1

print ("the number of vowels in the following string are",vowels)
# Out:
# enter anything here:  hi
# the number of vowels in the following string are 1

# %%
# write a program to find number of vowels in a string

a = input("Enter anything here: ")

vowels = 0

for i in a:
    if i in "aeiouAEIOU":
        vowels += 1

print("The number of vowels in the following string are", vowels)
# Out:
# Enter anything here:  23
# The number of vowels in the following string are 0

# %%
#write a program to check if every word in a string
#begins with a capital letter.
a = input("Enter anything here: ")
print (a.istitle())
# Out:
# Enter anything here:  ANNA
# False

# %%
#write a program to check if every word in a string
#begins with a capital letter.
a = input("Enter anything here: ")
print (a.istitle())
# Out:
# Enter anything here:  KHADIZA
# False

# %%
fruits = ["apple","mango", "banana"]
print (fruits)
print (type(fruits))
# Out:
# ['apple', 'mango', 'banana']
# <class 'list'>

# %%
fruits = ["apple","mango", "banana","12","14","45.5"]
print (fruits)
print (type(fruits))
# Out:
# ['apple', 'mango', 'banana', '12', '14', '45.5']
# <class 'list'>

# %%
a = ["Ironman","Thor","Captain America","Hulk"]
print (a[2])
print (a[-3])
print (a[1:3])
print (a[:2])
print (a[1:])
print (a[::2])
print (a[-3:-1])
print (a[::-1])
print (a[-1:-4:-1])
# Out:
# Captain America
# Thor
# ['Thor', 'Captain America']
# ['Ironman', 'Thor']
# ['Thor', 'Captain America', 'Hulk']
# ['Ironman', 'Captain America']
# ['Thor', 'Captain America']
# ['Hulk', 'Captain America', 'Thor', 'Ironman']
# ['Hulk', 'Captain America', 'Thor']

# %%
#Iteration Using For Loop
a = ["Hulk","Thor","Ironman","Captain America"]
for i in a:
    print (i)

#Iteration Using For Loop with Range and Length function
for i in range (len(a)):
    print (a[i])

#Iteration Using While Loop
i = 0
while i <(len(a)):
    print (a[i])
    i +=1

#Using Short-Hand For Loop
[print (i) for i in a]
# Out:
# Hulk
# Thor
# Ironman
# Captain America
# Hulk
# Thor
# Ironman
# Captain America
# Hulk
# Thor
# Ironman
# Captain America
# Hulk
# Thor
# Ironman
# Captain America
# [None, None, None, None]

# %%
a = ["Thor","Hulk","Ironman","Captain America"]
print (a)
# to find the length of a list
print (len(a))

# to count an occurance of a particular element
a = ["Thor","Hulk","Ironman","Captain America","Hulk"]
print (a.count("Hulk"))

# to add to the list
a.append("Spiderman")
print (a)

# to add to a specific location
a.insert(1,"Vision")
print (a)

# to remove from a list
a.remove("Hulk")
print (a)

# to remove from a certain location
print (a.pop(2))
print (a)
# Out:
# ['Thor', 'Hulk', 'Ironman', 'Captain America']
# 4
# 2
# ['Thor', 'Hulk', 'Ironman', 'Captain America', 'Hulk', 'Spiderman']
# ['Thor', 'Vision', 'Hulk', 'Ironman', 'Captain America', 'Hulk', 'Spiderman']
# ['Thor', 'Vision', 'Ironman', 'Captain America', 'Hulk', 'Spiderman']
# Ironman
# ['Thor', 'Vision', 'Captain America', 'Hulk', 'Spiderman']

# %%
a = ["Thor","Hulk","Ironman","Captain America"]
#to create a copy of a list
b = []
print (b)
b = a.copy ()
print (b)

#to access an element
print (a.index("Ironman"))

#to entend the list
c = ["Vision","Spiderman"]
a.extend (c)
print(a)

#to reverse the list
a.reverse()
print (a)

#to sort the list
d = [1,4,6,8,5,2]
d.sort()
print (d)
a.sort()
print (a)

#to clear allthe data from the list
a.clear()
print (a)
d.clear()
print(d)
# Out:
# []
# ['Thor', 'Hulk', 'Ironman', 'Captain America']
# 2
# ['Thor', 'Hulk', 'Ironman', 'Captain America', 'Vision', 'Spiderman']
# ['Spiderman', 'Vision', 'Captain America', 'Ironman', 'Hulk', 'Thor']
# [1, 2, 4, 5, 6, 8]
# ['Captain America', 'Hulk', 'Ironman', 'Spiderman', 'Thor', 'Vision']
# []
# []

# %%
l1 = [30,40,50,60]

l2 = []
for i in l1:
    if i >45:
       l2.append (i)
print (l1,"\n",l2)

l3 = [i for i in l1]
print (l3)
# Out:
# [30, 40, 50, 60]
#  [50, 60]
# [30, 40, 50, 60]

# %%
A = ["Ross" , "Rachel" , "Monica" , "Joe"]
# Write a program to swap first and forth element.

A[0],A[3]=A[3],A[0]
print (A)

# Write a program to add a new value at second position.

A.insert(1,"Phoebe")
print (A)


# Write a program to delete a value from 3rd position.

A.pop(2)
print (A)


B = [13 , 7 , 12 , 10 ]
# Write a program to multiply all the numbers in the list.

mul = 1
for i in (B):
    mul*=i
print (mul)


# Write a program to get the largest number from the list.
# Arrange thelidt ascending order

B.sort()
print (B)
print ("The largest value in the given list is",B[-1])
print ("The smallest value in the given list is",B[0])

# Write a program to get the smallest number from the list.
B.sort()
print (B)
print ("The largest value in the given list is",B[-1])
# Out:
# ['Joe', 'Rachel', 'Monica', 'Ross']
# ['Joe', 'Phoebe', 'Rachel', 'Monica', 'Ross']
# ['Joe', 'Phoebe', 'Monica', 'Ross']
# 10920
# [7, 10, 12, 13]
# The largest value in the given list is 13
# The smallest value in the given list is 7
# [7, 10, 12, 13]
# The largest value in the given list is 13

# %%
# Tuples
a = ("apple","mango","banana")
print (type(a))
a = "apple","mango","banana",1,67,1.23
print(a)
b = "Ironman"
print (type(b))
# Out:
# <class 'tuple'>
# ('apple', 'mango', 'banana', 1, 67, 1.23)
# <class 'str'>

# %%
a = ("Oneplus","Vivo","Redmi","Sumsung","Nokia")
print (a[1:3])
print (a[:3])
print (a[2:])
print (a[::2])
print (a[1::2])
print (a[::-1])
print (a[2::-1])
# Out:
# ('Vivo', 'Redmi')
# ('Oneplus', 'Vivo', 'Redmi')
# ('Redmi', 'Sumsung', 'Nokia')
# ('Oneplus', 'Redmi', 'Nokia')
# ('Vivo', 'Sumsung')
# ('Nokia', 'Sumsung', 'Redmi', 'Vivo', 'Oneplus')
# ('Redmi', 'Vivo', 'Oneplus')

# %%
a = ("Oneplus","Vivo","Redmi","Sumsung","Nokia")
#with for loop
for i in a:
    print (i)

#along with range and length in for loop
for i in range (len(a)):
    print (a[i])

#along with while loop
i = 0
while i < len (a):
    print (a[i])
    i+=1
# Out:
# Oneplus
# Vivo
# Redmi
# Sumsung
# Nokia
# Oneplus
# Vivo
# Redmi
# Sumsung
# Nokia
# Oneplus
# Vivo
# Redmi
# Sumsung
# Nokia

# %%
a = ("Oneplus","Nokia","Redmi")

print (a.count("Redmi"))


print (a.index("Nokia"))

print ("the index of nokia is",a.index("Nokia"))

#print ("brfore conversion",type(a))
#a = list (a)
#print ("after conversion",type(a))
#a.append("Vivo")
#print (a)
#a = tuple (a)
#print (type(a))
#print (a)
# Out:
# 1
# 1
# the index of nokia is 1

# %%
#Convert the following dictionary in JSON format.

#import json
#Student_data = {"name": "David","age":13,"marks":87}
#print (type(Student_data))
#data = json.dumps(Student_data)
#print (data)
#print (type(data))


#Access the value of age from the given data.
#Student_data = """{"name": "David","age":13,"marks":87}"""

#data = json.loads(Student_data)
#print (data["age"])

#Pretty Print following JSON data.

#Student_data = {"name": "David","age":13,"marks":87}
#data = json.dumps(Student_data,indent=4,separators=(",","="))
#print(data)

#Sort the following JSON keys and write them into a file.
#Student_data = {"name": "David","age":13,"marks":87}
#f = open("demo.json","w")
#data = json.dumps(Student_data,indent=4,sort_keys=True)
#f.write(data)

#print ("the data has been added to the file")



#Access the nested key "marks" from the following nested data
import json

Student_data = """{
    "student":{
        "grade":{
            "name":"David",
            "marks":87
        }
    }
}"""

data = json.loads(Student_data)

print(data["student"]["grade"]["marks"])
# Out:
# 87

# %%
#DICTIONARY

Employee_Data = {"name":"khadiza","age":"24","gender":"male"}
print (Employee_Data)
print (Employee_Data["age"])
print (Employee_Data["gender"])
# Out:
# {'name': 'khadiza', 'age': '24', 'gender': 'male'}
# 24
# male

# %%
#Iteration in Dictionary
Student = {"name":"khadiza","class":"6th","roll_no":"23"}
#printing all the key names one by one
for x in Student:
    print (x)
#printing all the value names one by one
for x in Student:
    print (Student[x])

#using value function

for x in Student.values():
    print (x)

for x,y in Student.items():
    print (x,":",y)
# Out:
# name
# class
# roll_no
# khadiza
# 6th
# 23
# khadiza
# 6th
# 23
# name : khadiza
# class : 6th
# roll_no : 23

# %%
#Dictionary Functions
Student={"name":"khadiza","class":"6th","roll_no":"23"}
#get
x = Student.get("name")
print (x)

#item
a = Student.items()
print (a)

#keys
b = Student.keys()
print (b)

#values
c = Student.values()
print(c)

#copy
d = Student.copy()
print (d)
# Out:
# khadiza
# dict_items([('name', 'khadiza'), ('class', '6th'), ('roll_no', '23')])
# dict_keys(['name', 'class', 'roll_no'])
# dict_values(['khadiza', '6th', '23'])
# {'name': 'khadiza', 'class': '6th', 'roll_no': '23'}

# %%
#ITERATION IN DICTIONARIES 2
#Student={"name":"khadiza","class":"6th","roll_no":"23"}
#setdefault
#x = Student.setdefault("roll_no",24)
#print (x)

#update

#pop

#popitem

#clear

Student = {
    "name": "khadiza",
    "class": "6th",
    "roll_no": "23"
}

print(Student)

x = Student.setdefault("roll_no", 24)

print(x)
print(Student)

Student.update({
    "section": "A",
    "name": "Expert Khadiza"
})

print(Student)

removed_value = Student.pop("class")

print(removed_value)
print(Student)

last_item = Student.popitem()

print(last_item)
print(Student)

Student.clear()

print(Student)
# Out:
# {'name': 'khadiza', 'class': '6th', 'roll_no': '23'}
# 23
# {'name': 'khadiza', 'class': '6th', 'roll_no': '23'}
# {'name': 'Expert Khadiza', 'class': '6th', 'roll_no': '23', 'section': 'A'}
# 6th
# {'name': 'Expert Khadiza', 'roll_no': '23', 'section': 'A'}
# ('section', 'A')
# {'name': 'Expert Khadiza', 'roll_no': '23'}
# {}

# %%
Employees = {1:{"name":"khadiza","age":"23","gender":"female"},
             2:{"name":"lisa","age":24,"gender":"female"},
             3:{"name":"mahbub","age":25,"gender":"male"}}
print (Employees)
print (Employees[2]["age"])
print (Employees[1]["gender"])
print (Employees[1])
# Out:
# {1: {'name': 'khadiza', 'age': '23', 'gender': 'female'}, 2: {'name': 'lisa', 'age': 24, 'gender': 'female'}, 3: {'name': 'mahbub', 'age': 25, 'gender': 'male'}}
# 24
# female
# {'name': 'khadiza', 'age': '23', 'gender': 'female'}

# %%
#write a python program to sort a dictionary by value.
a = {"a":12,"b":23,"c":6,"d":91,"e":45}
a = sorted(a.values())
print (a)

#write a python script to print a dictionary
#where the keys are numbers between 1 and 15 and the
#values are square of keys.
a = {}
for i in range (1,16):
    a[i] = i**2

print (a)


#write a program to multiply all the items in a dictionary.
a = {"a":1,"b":2,"c":3,"d":4,"e":5}
print (a["c"])
product = 1
for i in a:
    product *=a[i]

print (product)


#write a python program to sort a dictionary by key.

a = {12:"a",23:"b",6:"c",91:"d",45:"e"}
a =sorted(a.keys())
print (a)
# Out:
# [6, 12, 23, 45, 91]
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100, 11: 121, 12: 144, 13: 169, 14: 196, 15: 225}
# 3
# 120
# [6, 12, 23, 45, 91]

# %%
#Sets
a = {"Ironman","Hulk","Thor","Captain America"}
print (a)
print (type(a)) 
for x in a:
    print (x)
# Out:
# {'Ironman', 'Hulk', 'Thor', 'Captain America'}
# <class 'set'>
# Ironman
# Hulk
# Thor
# Captain America

# %%
a = {"Ironman","Hulk","Thor","Captain America"}
#add
a.add("Spiderman")
print(a)

#pop
#a.pop()
print (a)

#remove
#a.remove("Thor")
print (a)

#discard
a.discard("Hulk")
print(a)

#copy
b = a.copy()
print (b)
# Out:
# {'Spiderman', 'Captain America', 'Ironman', 'Thor', 'Hulk'}
# {'Spiderman', 'Captain America', 'Ironman', 'Thor', 'Hulk'}
# {'Spiderman', 'Captain America', 'Ironman', 'Thor', 'Hulk'}
# {'Spiderman', 'Captain America', 'Ironman', 'Thor'}
# {'Ironman', 'Spiderman', 'Captain America', 'Thor'}

# %%
a = {"Ironman","Hulk","Thor","Captain America"}
b = {"Superman","Batman","Wonder-Wonder"}
c = {"Hulk","Thor","Spiderman"}


#isdisjoint
print (a.isdisjoint(b))

#issubset
print (a.issubset(b))
print (c.issubset(a))

#issuperset
print (b.issuperset(a))
print (a.issuperset(c))

#isupdate
a.update(c)
print (a)

#clear
print (a.clear())
print(a)
# Out:
# True
# False
# False
# False
# False
# {'Ironman', 'Spiderman', 'Thor', 'Hulk', 'Captain America'}
# None
# set()

# %%
a = {"Ironman","Hulk","Thor","Captain America"}
b = {"Superman","Batman","Wonder-Wonder"}
c = {"Hulk","Thor","Spiderman"}
#union
#print (a.union(c))

#difference
#print (a.difference(c))
#print (x)
            


#difference update
#a.difference_update(c)
#print(a)

#intersection
#print(a.intersection(c))
#x= (a.intersection(c))
print (x)

#intersection update
#a.intersection_update(c)
print (a)

#symmetric difference
x =a.symmetric_difference(c)
print(x)


#symmetric difference update 
a.symmetric_difference_update(c)
print (a)
# Out:
# Captain America
# {'Ironman', 'Hulk', 'Thor', 'Captain America'}
# {'Spiderman', 'Captain America', 'Ironman'}
# {'Ironman', 'Spiderman', 'Captain America'}

# %%
#write a program to find max and min in a set.
a = {12,56,34,8,90,1,57}
#maximum =max(a)
#minimum =min(a)
#print ("the maximum value in the given set is",maximum)
#print ("the minimum value ine given set is",minimum)


#write a program to find common elements in 
#three lists using sets.
# a = [1,5,6,8,2]
# b = [4,5,6,7]
# c = [1,9,6,2,5]

# print ("the common elements in the given three lists are",set(a) & set (b) & set(c))

#write program to find difference beteen two sets.

# a = {1,5,6,8,2}
# b = {1,9,6,2,5}

# print (a.difference (b))
# print (b.difference (a))

#write a python program to remove an item from
#a set if it is present in the set.
# a = {1,5,6,8,2}
# a.discard(8)
# print (a)


#write a python program to check if a set
#is a subset of another set
a ={1,2,3,4,5,6}
b = {2,3,4}

print (b.issubset (a))
# Out:
# True

# %%
#defination & call of function
def hello():
    print ("hello world")

hello()

def add():
    x = 56
    y =23
    print(x+y)
add()
# Out:
# hello world
# 79

# %%
#parameters and arguments
#def add (x,y): ->parameters
    #print(x+y)
#add(2,3)->arguements
#add(4,7)->arguements

def add (x,y): 
    print(x+y)

add(12,67)
add(12,56)
# Out:
# 79
# 68

# %%
def rect(length,width):
    print ("the area of the rectangle is", length*width)

rect(12,3)
# Out:
# the area of the rectangle is 36

# %%
#arbitary arguements
def hello(*name):
    print ("hello my name is",name)
    print ("hello my name is",name[1])
    print ("hello my name is",name[0])
    print ("hello my name is",name[2])
hello("khadiza","lisa","dear")
# Out:
# hello my name is ('khadiza', 'lisa', 'dear')
# hello my name is lisa
# hello my name is khadiza
# hello my name is dear

# %%
#Return statement and recursion in python

def hello():
    return("hello world")
print (hello())

def add (a,b):
    return ("the addition of two numbers is",a+b)
print (add(12,4))

# #Recursion
# def hello():
#     print("helllo")
#     return hello()
# print (hello())

def fact (n):
    if n == 1:
        return 1
    else:
        return (n*fact(n-1))
print (fact(5))
# Out:
# hello world
# ('the addition of two numbers is', 16)
# 120

# %%
# #Lambda funtion in python 
# a = lambda b: b*5 
# print (a(4))
x = lambda a,b,c: (a+b)*c
print (x(3,7,3))
# Out:
# 30

# %%
#Local Variables:
#Global Varibles:

x = 24
print ("first varible x", x)
def hello():
    global x
    x = 25
    return x
print (hello())
print (x)
# Out:
# first varible x 24
# 25
# 25

# %%
# Write a function to find maximum of three numbers in Python.

def maximum_num (val1,val2,val3):
    if val1 > val2 and val1>val3:
        print (val1,"is the greatest number")
    elif val2 > val1 and val2 >val3:
        print (val1,"is the greatest number")
    else:
        print (val3,"is the greatest number")
maximum_num(12,5,9)

# Write a Python function to create and print a list where the 
# values are square of numbers between 1 and 30.
def create_list():
    l = []
    for i in range (1,31):
        l.append(i**2)

    return l
print (create_list())


# Write a Python function that takes a number as a parameter 
# and check if the number is prime or not.

def check_prime(num):
    if num ==1:
        print ("it is not a prime number")
    if num ==2:
        print ("it is not a prime number")
    if num>2:
        for i in range (2,num):
            if num %i ==0:
                print ("it is not a prime number")
                break
        else:
            print ("it is a prime number")
check_prime(11)
check_prime(30)
            
# Write a Python function to sum all the numbers in a list.
def add (numbers):
    total = 0
    for i in numbers:
        total = total+i
    return (total)

print("the sum of all the items in the list is",add([12,4,5,6,7,8]))


# Write a Python program to solve the Fibonacci Sequence
#solution2 (using Recursion)

def add(numbers):

    if len(numbers) == 1:
        return numbers[0]

    else:
        return numbers[0] + add(numbers[1:])

print(add([12,4,5,6,7,8]))

def fs(num):
    if num == 1:
        return (0)
    elif num == 2:
        return (1)
    else:
        return (fs(num-1)+fs(num-2))

print (fs(7))
# Out:
# 12 is the greatest number
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100, 121, 144, 169, 196, 225, 256, 289, 324, 361, 400, 441, 484, 529, 576, 625, 676, 729, 784, 841, 900]
# it is a prime number
# it is not a prime number
# the sum of all the items in the list is 42
# 42
# 8

# %%
#in-built modules
import datetime

x = datetime.datetime.now()
print (x)
y = datetime.datetime(1997,10,14)
print (y)

y = datetime.datetime(1997,10,14)
print (y.strftime("%A"))
print (y.strftime("%B"))
print (y.strftime("%y"))
# Out:
# 2026-05-29 00:34:03.485288
# 1997-10-14 00:00:00
# Tuesday
# October
# 97

# %%
#Random modules
import random
x = random.randint(1,10)
print (x)
import random
l = ["Heads","Tails"]
x = random.choice(l)
print (x)
# Out:
# 8
# Tails

# %%
#math modules
import math
x = max(13,67,45)
print ("the maximum value is",x)
y = min (13,67,45)
print ("the minimum value is",y)

a = pow(2,4)
print (a)

b = math.sqrt(49)
print (b)

c = abs (-12)
print (c)

k = math.ceil(2.4)
print (k)

m = math.floor(2.4)
print (m)
# Out:
# the maximum value is 67
# the minimum value is 13
# 16
# 7.0
# 12
# 3
# 2

# %%
import loops practice2,tuples,JSON
a =  loops practice2,tuples,JSON.add(2,3)
print (a)

import demo01
a = demo01.add(2,3)
print (a)
# Out:
#   Cell In[94], line 1
#     import loops practice2,tuples,JSON
#                  ^
# SyntaxError: invalid syntax
