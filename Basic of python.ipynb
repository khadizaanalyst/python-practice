# %%
print ("hello khadiza")
# Out:
# hello khadiza

# %%
a =5 
b = 10
print (a+b)
# Out:
# 15

# %%
name = "khadiza"
print ("my name is", name)
# Out:
# my name is khadiza

# %%
import pandas as pd

df = pd.DataFrame({"Name": ["A","B", "C" ], "Age" :["20","21","22"]})
display (df)
# Out:
#   Name Age
# 0    A  20
# 1    B  21
# 2    C  22

# %%
_name = "dear khadiza"
print (_name)
# Out:
# dear khadiza

# %%
Nick_name = "dear khadiza"
print (Nick_name)
# Out:
# dear khadiza

# %%
channel1name50k = "dear khadiza"
print (channel1name50k)
# Out:
# dear khadiza

# %%
x = 5
print (type(x))
# Out:
# <class 'int'>

# %%
a = "dear khadiza"
b = 50
c = 60.5
d = 3j
print (a)
print (b)
print (c)
print (d)
# Out:
# dear khadiza
# 50
# 60.5
# 3j

# %%
e = ["wecome","to","bangladesh"]
print (e)
# Out:
# ['wecome', 'to', 'bangladesh']

# %%
e = ["welcome","to","bangladesh"]
print (e[2])
# Out:
# bangladesh

# %%
e = ["welcome","to","bangladesh"]
print (len(e))
# Out:
# 3

# %%
e = ["welcome","to","bangladesh"]
e.append("today")
print (e)
# Out:
# ['welcome', 'to', 'bangladesh', 'today']

# %%
e = ["welcome","to","bangladesh"]
print (" ".join(e))
# Out:
# welcome to bangladesh

# %%
e = ["welcome","to","bangladesh"]
e.remove("to")
print (e)
# Out:
# ['welcome', 'bangladesh']

# %%
e = ["welcome","to","bangladesh"]
e.reverse ()
print (e)
# Out:
# ['bangladesh', 'to', 'welcome']

# %%
g = range (10)
print (g)
# Out:
# range(0, 10)

# %%
i = {"welcome","to","bangladesh"}
print (i)
# Out:
# {'welcome', 'bangladesh', 'to'}

# %%
age = 19
if age >=18:
    print ("you are an adult.")
else:
    print ("you are not an adult.")
# Out:
# you are an adult.

# %%
score = 75

if score >= 90:
    grade ='A'
elif score >= 80:  
    grade = 'B'
elif score >= 70:
    grade = 'C'
else:
    grade = 'D'

print ("your grade is:", grade)
# Out:
# your grade is: C

# %%
score = 65

if score >= 90:
    grade ='A'
elif score >= 80:  
    grade = 'B'
elif score >= 70:
    grade = 'C'
else:
    grade = 'D'

print ("your grade is:", grade)
# Out:
# your grade is: D

# %%
count = 0
while count <5:
    print ("count is", count)
    count += 1
# Out:
# count is 0
# count is 1
# count is 2
# count is 3
# count is 4
