# %%
# Bar Plot-Matplotlib
import matplotlib.pyplot as plt

y = [98,67,88,95,88]
x = ["Part1","Part2","Part3","Part4","Part5"]

color =["red","green","yellow","blue","orange"]
plt.bar(x , y,color=color,edgecolor ="black")
plt.xlabel("Parts of Harry Potter",fontsize =17)
plt.ylabel("Popularity",fontsize =17)
plt.title("Popularity of Differrent parts of Harry Potter",fontsize =20)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_excel("C:/Users/HP/Downloads/employee_sales_practice.xlsx")

df = pd.DataFrame(data)
print (df)

plt.bar(df["Name"], df["Salary"], color="skyblue")
plt.xlabel("Name")
plt.ylabel("Salary")
plt.title("Employee Salary")
plt.show()
# Out:
#    ID   Name  Age        City Department  Salary  Sales    JoinDate
# 0   1  Rahim   22       Dhaka      Sales   25000  15000  2022-01-15
# 1   2  Karim   25  Chattogram  Marketing   30000  22000  2021-06-10
# 2   3  Hasan   21      Sylhet      Sales   24000  18000  2023-03-01
# 3   4  Nadia   24       Dhaka         IT   35000  16000  2020-11-20
# 4   5  Sadia   23    Rajshahi  Marketing   30000  12000  2022-09-05
# 5   6  Rakib   29       Dhaka         IT   40000  20000  2019-02-14
# 6   7  Rakib   29       Dhaka         IT   40000  20000  2019-02-14

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_excel("C:/Users/HP/Downloads/employee_sales_practice.xlsx")

df = pd.DataFrame(data)
print (df)
avg_salary = df.groupby("Department")["Salary"].mean()
plt.bar(avg_salary.index, avg_salary.values, color="orange")
plt.xlabel("Department")
plt.ylabel("Average Salary")
plt.title("Average Salary by Department")
plt.show()
# Out:
#    ID   Name  Age        City Department  Salary  Sales    JoinDate
# 0   1  Rahim   22       Dhaka      Sales   25000  15000  2022-01-15
# 1   2  Karim   25  Chattogram  Marketing   30000  22000  2021-06-10
# 2   3  Hasan   21      Sylhet      Sales   24000  18000  2023-03-01
# 3   4  Nadia   24       Dhaka         IT   35000  16000  2020-11-20
# 4   5  Sadia   23    Rajshahi  Marketing   30000  12000  2022-09-05
# 5   6  Rakib   29       Dhaka         IT   40000  20000  2019-02-14
# 6   7  Rakib   29       Dhaka         IT   40000  20000  2019-02-14

# %%
#PieChart
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_excel("C:/Users/HP/Downloads/employee_sales_practice.xlsx")

df = pd.DataFrame(data)
print (df)
city_counts = df["City"].value_counts()
plt.pie(city_counts.values, labels=city_counts.index, autopct="%1.1f%%")
plt.title("Employees by City")
plt.show()
# Out:
#    ID   Name  Age        City Department  Salary  Sales    JoinDate
# 0   1  Rahim   22       Dhaka      Sales   25000  15000  2022-01-15
# 1   2  Karim   25  Chattogram  Marketing   30000  22000  2021-06-10
# 2   3  Hasan   21      Sylhet      Sales   24000  18000  2023-03-01
# 3   4  Nadia   24       Dhaka         IT   35000  16000  2020-11-20
# 4   5  Sadia   23    Rajshahi  Marketing   30000  12000  2022-09-05
# 5   6  Rakib   29       Dhaka         IT   40000  20000  2019-02-14
# 6   7  Rakib   29       Dhaka         IT   40000  20000  2019-02-14

# %%
import matplotlib.pyplot as plt
brands =["Oneplus","Apple","Samsung","Nokia","Redmi"]
x = [22,35,30,3,10]
c = ["red","yellow","blue","magenta","orange"]
ex =[0,0,0,0,0.1]
plt.pie(x,labels =brands, colors =c,explode= ex,shadow =True,autopct ="%.2f",startangle =90)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_excel("C:/Users/HP/Downloads/employee_sales_practice.xlsx")
df = pd.DataFrame(data)
plt.pie(df["Sales"].fillna(0),labels =df["City"])
plt.show()
print(df)
# Out:
#    ID   Name  Age        City Department  Salary  Sales    JoinDate
# 0   1  Rahim   22       Dhaka      Sales   25000  15000  2022-01-15
# 1   2  Karim   25  Chattogram  Marketing   30000  22000  2021-06-10
# 2   3  Hasan   21      Sylhet      Sales   24000  18000  2023-03-01
# 3   4  Nadia   24       Dhaka         IT   35000  16000  2020-11-20
# 4   5  Sadia   23    Rajshahi  Marketing   30000  12000  2022-09-05
# 5   6  Rakib   29       Dhaka         IT   40000  20000  2019-02-14
# 6   7  Rakib   29       Dhaka         IT   40000  20000  2019-02-14

# %%
import pandas as pd
import matplotlib.pyplot as plt

data =pd.read_excel("C:/Users/HP/Downloads/expense_tracker_practice.xlsx")
df =pd.DataFrame(data)
grouped_by =df.groupby("PaymentMode")["Amount"].sum()
print(grouped_by )
plt.pie(grouped_by.values,labels = grouped_by.index,autopct ="%2f")
plt.show()
print(df)
# Out:
# PaymentMode
# Card       7599
# Cash       8160
# Online    10600
# Name: Amount, dtype: int64
#           Date       Category   SubCategory  Amount PaymentMode
# 0   2024-01-03           Food     Groceries    1200        Cash
# 1   2024-01-05      Transport      Bus Fare      50        Cash
# 2   2024-01-07           Food    Restaurant     850        Card
# 3   2024-01-10          Bills   Electricity    2200      Online
# 4   2024-01-12       Shopping      Clothing    3500        Card
# 5   2024-01-15           Food     Groceries    1100        Cash
# 6   2024-01-18  Entertainment        Movies     600        Card
# 7   2024-01-20      Transport          Fuel    2500      Online
# 8   2024-01-22          Bills      Internet    1000      Online
# 9   2024-01-25           Food    Restaurant     950        Card
# 10  2024-01-27       Shopping   Electronics    4200      Online
# 11  2024-01-28         Health      Medicine     450        Cash
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_excel("C:/Users/HP/Downloads/employee_sales_practice.xlsx")

df = pd.DataFrame(data)
print (df)
sorted_df = df.sort_values("Age")
plt.plot(sorted_df["Age"], sorted_df["Salary"], marker="o")
plt.xlabel("Age")
plt.ylabel("Salary")
plt.title("Age vs Salary")
plt.show()
# Out:
#    ID   Name  Age        City Department  Salary  Sales    JoinDate
# 0   1  Rahim   22       Dhaka      Sales   25000  15000  2022-01-15
# 1   2  Karim   25  Chattogram  Marketing   30000  22000  2021-06-10
# 2   3  Hasan   21      Sylhet      Sales   24000  18000  2023-03-01
# 3   4  Nadia   24       Dhaka         IT   35000  16000  2020-11-20
# 4   5  Sadia   23    Rajshahi  Marketing   30000  12000  2022-09-05
# 5   6  Rakib   29       Dhaka         IT   40000  20000  2019-02-14
# 6   7  Rakib   29       Dhaka         IT   40000  20000  2019-02-14

# %%
#Lineplot
import matplotlib.pyplot as plt
x =["day1","day2","day3","day4","day5"]
y = [300,420,250,230,400]
plt.plot(x,y,marker ="o")
plt.show()

# %%
import matplotlib.pyplot as plt
x =["day1","day2","day3","day4","day5"]
y = [300,420,250,230,400]
y1 = [500,450,300,250,320]

plt.plot(x,y,marker ="o",ls = "--",color ="red",label ="week1")
plt.plot(x,y1,marker ="*",ls = "-",color ="blue",label = "week2",alpha =0.5)
plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_excel("C:/Users/HP/Downloads/employee_sales_practice.xlsx")
df = pd.DataFrame(data)
grouped_by =df.groupby("Age")["Sales"].sum()
print(grouped_by)
plt.plot(grouped_by.index,grouped_by.values)
print(df)
plt.show()
# Out:
# Age
# 21    18000
# 22    15000
# 23    12000
# 24    16000
# 25    22000
# 29    40000
# Name: Sales, dtype: int64
#    ID   Name  Age        City Department  Salary  Sales    JoinDate
# 0   1  Rahim   22       Dhaka      Sales   25000  15000  2022-01-15
# 1   2  Karim   25  Chattogram  Marketing   30000  22000  2021-06-10
# 2   3  Hasan   21      Sylhet      Sales   24000  18000  2023-03-01
# 3   4  Nadia   24       Dhaka         IT   35000  16000  2020-11-20
# 4   5  Sadia   23    Rajshahi  Marketing   30000  12000  2022-09-05
# 5   6  Rakib   29       Dhaka         IT   40000  20000  2019-02-14
# 6   7  Rakib   29       Dhaka         IT   40000  20000  2019-02-14

# %%
# Scatter Plot
import matplotlib.pyplot as plt
import numpy as np

x = np.random.randint(1,10,50)
y = np.random.randint(10,100,50)
plt.scatter(x,y,marker ="*",color ="red")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.randint(1,10,50)
y = np.random.randint(10,100,50)
color = np.random.randint(10,100,50)
size = np.random.randint(10,100,50)

plt.scatter(x,y,marker ="*",cmap ="hot", c = color,s =size)
plt.colorbar()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

data = pd.read_excel("C:/Users/HP/Downloads/employee_sales_practice.xlsx")

df = pd.DataFrame(data)
print(df)
plt.scatter(df["Age"],df["ID"],s =df["Salary"])
plt.show()
# Out:
#    ID   Name  Age        City Department  Salary  Sales    JoinDate
# 0   1  Rahim   22       Dhaka      Sales   25000  15000  2022-01-15
# 1   2  Karim   25  Chattogram  Marketing   30000  22000  2021-06-10
# 2   3  Hasan   21      Sylhet      Sales   24000  18000  2023-03-01
# 3   4  Nadia   24       Dhaka         IT   35000  16000  2020-11-20
# 4   5  Sadia   23    Rajshahi  Marketing   30000  12000  2022-09-05
# 5   6  Rakib   29       Dhaka         IT   40000  20000  2019-02-14
# 6   7  Rakib   29       Dhaka         IT   40000  20000  2019-02-14

# %%
# Box plot

import matplotlib.pyplot as plt

m = [25,46,57,25,45,13,29,39,46,99,22,12,14,16,55,6,46,52,55,78]
plt.boxplot(m)
plt.show()

# %%
import matplotlib.pyplot as plt

m = [1,3,4,7,12,2,8,9,24]
plt.boxplot(m)
plt.show()

# %%
import matplotlib.pyplot as plt

m = [1,3,4,7,12,2,8,9,24]
m1 = [2,3,4,6,3,5,7,3,6]
plot_values = [m,m1]
plt.boxplot(plot_values)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data =pd.read_excel("C:/Users/HP/Downloads/expense_tracker_practice.xlsx")
df =pd.DataFrame(data)
plt.boxplot(df["Amount"])
plt.show()

# %%
# Histogram Plot

import matplotlib.pyplot as plt

x = [30,40,68,27,47,59,47,88,44,23,44,66,66,33,5,2,5,50,12,17,16]

plt.hist(x, bins = 20)
plt.show()

# %%
import matplotlib.pyplot as plt

x = [30,40,68,27,47,59,47,88,44,23,44,66,66,33,5,2,5,50,12,17,16]

plt.hist(x, bins = len(x),edgecolor ="black", color = "skyblue")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_excel("C:/Users/HP/Downloads/employee_sales_practice.xlsx")
df = pd.DataFrame(data)
print(df)

plt.hist(df["Age"], bins =10, edgecolor ="black", color = "yellow")
plt.show()
# Out:
#    ID   Name  Age        City Department  Salary  Sales    JoinDate
# 0   1  Rahim   22       Dhaka      Sales   25000  15000  2022-01-15
# 1   2  Karim   25  Chattogram  Marketing   30000  22000  2021-06-10
# 2   3  Hasan   21      Sylhet      Sales   24000  18000  2023-03-01
# 3   4  Nadia   24       Dhaka         IT   35000  16000  2020-11-20
# 4   5  Sadia   23    Rajshahi  Marketing   30000  12000  2022-09-05
# 5   6  Rakib   29       Dhaka         IT   40000  20000  2019-02-14
# 6   7  Rakib   29       Dhaka         IT   40000  20000  2019-02-14

# %%
# Violin Plot
import matplotlib.pyplot as plt
a =[20,30,50,40,0,30,40,40,30,30,70,80,40,20]

plt.violinplot(a,showmedians = True)
plt.show()

# %%
import matplotlib.pyplot as plt
a =[20,30,50,40,0,30,40,40,30,30,70,80,70,75,80,82,88,40,20]

plt.violinplot(a,showmedians = True)
plt.show()

# %%
import pandas as pd
data = pd.read_excel("C:/Users/HP/Downloads/employee_sales_practice.xlsx")
df =pd.DataFrame(data)
print (df)

plt.violinplot(df["Age"],showmedians = True)
plt.show()
# Out:
#    ID   Name  Age        City Department  Salary  Sales    JoinDate
# 0   1  Rahim   22       Dhaka      Sales   25000  15000  2022-01-15
# 1   2  Karim   25  Chattogram  Marketing   30000  22000  2021-06-10
# 2   3  Hasan   21      Sylhet      Sales   24000  18000  2023-03-01
# 3   4  Nadia   24       Dhaka         IT   35000  16000  2020-11-20
# 4   5  Sadia   23    Rajshahi  Marketing   30000  12000  2022-09-05
# 5   6  Rakib   29       Dhaka         IT   40000  20000  2019-02-14
# 6   7  Rakib   29       Dhaka         IT   40000  20000  2019-02-14

# %%
import pandas as pd
data = pd.read_excel("C:/Users/HP/Downloads/employee_sales_practice.xlsx")
df =pd.DataFrame(data)
print (df)

plt.violinplot(df["Salary"],showmedians = True)
plt.show()
# Out:
#    ID   Name  Age        City Department  Salary  Sales    JoinDate
# 0   1  Rahim   22       Dhaka      Sales   25000  15000  2022-01-15
# 1   2  Karim   25  Chattogram  Marketing   30000  22000  2021-06-10
# 2   3  Hasan   21      Sylhet      Sales   24000  18000  2023-03-01
# 3   4  Nadia   24       Dhaka         IT   35000  16000  2020-11-20
# 4   5  Sadia   23    Rajshahi  Marketing   30000  12000  2022-09-05
# 5   6  Rakib   29       Dhaka         IT   40000  20000  2019-02-14
# 6   7  Rakib   29       Dhaka         IT   40000  20000  2019-02-14

# %%
# Stem Plot

import matplotlib.pyplot as plt
x = [20,30,50,45,45,63,23,67,85,47,40,50]

plt.stem(x,linefmt ="--",markerfmt ="D",orientation ="horizontal")
plt.show()

# %%
import pandas as pd
data = pd.read_excel("C:/Users/HP/Downloads/employee_sales_practice.xlsx")
df =pd.DataFrame(data)
df2 =(df.head(5))
plt.stem(df["Age"])
plt.plot(df["Age"])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Stack Plot
import matplotlib.pyplot as plt
days = [1,2,3,4,5,6,7]
NOP1 = [5,10,30,20,35,60,80]
NOP2 = [10,20,30,25,40,50,90]
NOP3 =[8,30,50,60,70,90,100]

plt.stackplot(days,NOP1,NOP2,NOP3)
plt.show()

# %%
import matplotlib.pyplot as plt
days = [1,2,3,4,5,6,7]
NOP1 = [5,10,30,20,35,60,80]
NOP2 = [50,60,30,75,80,90,120]
NOP3 =[8,30,50,60,70,90,100]

plt.stackplot(days,NOP1,NOP2,NOP3,colors =["hotpink","yellow","blue"],labels =["week1","week2","week3"])
plt.legend()
plt.show()

# %%
import pandas as pd
data = pd.read_excel("C:/Users/HP/Downloads/nutrition_practice.xlsx")
df =pd.DataFrame(data)
#print(df)

grouped = df.groupby(["Category"])[["Calories","Protein","Fat"]].mean()
print(grouped)
plt.stackplot(df["Category"].unique(), grouped["Calories"], grouped["Protein"], grouped["Fat"])
plt.show()
# Out:
#              Calories    Protein        Fat
# Category
# Beverage    38.666667   0.666667   0.166667
# Dairy      137.333333   7.666667   8.333333
# Fruit       99.666667   1.066667   0.433333
# Grain      186.666667   4.633333   1.266667
# Protein    150.333333  19.100000   7.300000
# Snack      162.500000   6.650000  14.000000
# Vegetable   74.000000   2.133333   0.200000
